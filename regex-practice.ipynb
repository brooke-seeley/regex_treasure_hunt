# %% [markdown]
# # Regex Practice Exercises

# %% [markdown]
# # Exercise 1: Email Validation
# Task: Write a function that checks if a given string is a valid email address.

# %%
# Example Input:
"user@example.com"
"user@.com"

# Expected Output:
True   # For the first input
False  # For the second input

# %%
def is_valid_email():
    pass

# %%
# Example emails:

# Valid email: alice.smith@example.com  
# Invalid email: john@com  
# Invalid email: jane_doe@domain.  
# Valid email: user123@my-domain.org  

valid_emails = ['alice.smith@example.com', 'user123@my-domain.org ']
invalid_emails = ["john@com", "jane_doe@domain."]

# %%
print([is_valid_email(email) for email in valid_emails])
print([is_valid_email(email) for email in invalid_emails])

# %% [markdown]
# # Exercies 2: Date Extraction
# Task: Write a function that extracts all dates from a given text in the format DD/MM/YYYY.

# %%
# Example Input:
"I have a meeting on 12/10/2024 and another on 05.11.2024."

# Expected Output:
['12/10/2024', '05/11/2024']

# %%
def extract_date():
    pass

# %%
s = "I have a deadline on 15/09/2023, and another event scheduled for 22/12/2024. Let's also plan for a meeting on 01/01/2025."

# %%
print(extract_date(s))

# %% [markdown]
# # Exercise 3: Phone Number Formatting
# Task: Write a function that formats a phone number to the standard format (XXX) XXX-XXXX.

# %%
# Example Input:
"1234567890"
"123-456-7890"

# Expected Output:
"(123) 456-7890"  # For both inputs

# %%
def format_phone():
    pass

# %%
# Phone numbers to format:  
phone_numbers = ['123456789', '987-654-3210', '555.123.4567', '(555)1234567']

# %%
print([format_phone(phone) for phone in phone_numbers])

# %% [markdown]
# # Exercise 4: Finding Words Starting with Vowels
# Task: Write a function that finds all words in a given string that start with a vowel.

# %%
# Example Input:
"An apple a day keeps the doctor away."

# Expected Output:
['An', 'apple', 'a', 'away']

# %%
def vowel_starts():
    pass

# %%
s = 'An umbrella is essential on a rainy evening, especially after an unexpected storm.'

print(vowel_starts(s))

# %% [markdown]
# # Exercise 5: Removing Punctuation
# Task: Write a function that removes all punctuation from a given string.

# %%
# Example Input:
"Hello, world! How's it going?"

# Expected Output:
"Hello world Hows it going"

# %%
def remove_punctuation():
    pass

# %%
s = "Hello there! How's everything going? It's been a while—let's catch up soon."

print(remove_punctuation(s))

# %% [markdown]
# # Exercise 6: Password Strength Checker
# Task: Write a function that checks if a password is strong.
# > A strong password must have at least one uppercase letter, one lowercase letter, one digit, one special character, and be at least 8 characters long.

# %%
# Example Input:
"Password123!"
"pass"

# Expected Output:
True   # For the first input
False  # For the second input

# %%
def is_strong_password():
    pass

# %%
weak_passwords = ['123456', 'password', 'letmein']
strong_passwords = ['Complex#Pass2024', 'Secure_P@ss1', 'Str0ngPass!2023']

# %%
print([weak_passwords(password) for password in weak_passwords])
print([strong_passwords(password) for password in strong_passwords])

# %% [markdown]
# # Exercise 7: IP Address Validation
# Task: Write a function that checks if a given string is a valid IPv4 address.
# > IPv4 is valid if for each of the 4 sets of numbers, they are separated by periods, and each between 0 - 255

# %%
# Example Input:
"192.168.0.1"
"256.100.50.25"

# Expected Output:
True   # For the first input
False  # For the second input

# %%
def is_valid_ip():
    pass

# %%
valid_ips = ['192.168.1.1', '10.0.0.255', '172.16.0.0']
invalid_ips = ['256.100.50.25', '192.168.0.999', '300.300.300.300']

# %%
print([is_valid_ip(ip) for ip in valid_ips])
print([is_valid_ip(ip) for ip in invalid_ips])

# %% [markdown]
# # Exercise 8: URL Validation
# Task: Write a function that checks if a given string is a valid URL.
# > Valid if it starts with http:// or https://, ends with .com, .org, or .net + potential subdomains

# %%
# Example Input:
"https://www.google.com"
"htp://invalid-url"

# Expected Output:
True   # For the first input
False  # For the second input

# %%
def is_valid_url():
    pass

# %%
valid_urls = ['https://www.google.com', 'http://example.org', 'ftp://fileserver.com/file.zip']
invalid_urls = ['htp://invalid-url', '://missing-protocol.com', 'http//missing-colon.com']

# %%
print([is_valid_url(url) for url in valid_urls])
print([is_valid_url(url) for url in invalid_urls])

# %% [markdown]
# # Exercise 9: Extracting Hashtags
# Task: Write a function that extracts all hashtags from a given string.

# %%
# Example Input:
"Love #Python programming. #regex is awesome!"

# Expected Output:
['#Python', '#regex']

# %%
def extract_hashtags():
    pass

# %%
s1 =  "Just finished a great workout! #fitness #healthylifestyle #GymLife   "
s2 = "Looking forward to #vacation and #traveling to new places.  "
s3 = "I love #coding in #Python. #DevLife  "

# %%
print(extract_hashtags(s1))
print(extract_hashtags(s2))
print(extract_hashtags(s3))
